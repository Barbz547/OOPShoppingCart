# %%
from IPython.display import clear_output as co

# Exotic Pet Store

# my class of inventory is going to have a list of stock
class Inventory:
    # don't need to pass anything to initialize
    def __init__(self):
        # animal object and how many we have
        self.stock = {}
    
    # fill up my inventory
    def restock(self):
        fox = Animal('Fennec Fox', 4500.0)
        wolf = Animal('Grey Wolf', 3200.0)
        llama = Animal('Llama', 1500.0)
        alpaca = Animal('Alpaca', 2000.0)
        capybara = Animal('Capybara', 3400.0)
        self.addtostock(fox, 8)
        self.addtostock(wolf, 1)
        self.addtostock(llama, 4)
        self.addtostock(alpaca, 1)
        self.addtostock(capybara, 2)
    
    # adding a new animal to my stock
    def addtostock(self, a, q):
        self.stock[a.name.lower()] = {
            'obj': a,
            'quantity': q
        }
        
    # remove an animal from my stock
    def removefromstock(self, item):
        pass

#my inventory will be full of animal objects
class Animal:
    def __init__(self, n, p):
        self.name = n
        self.price = p
    
    def show(self):
        print(f'This is a {self.name} - it costs ${self.price:.2f}')
        
  
        
class Cart:
    # what is this person planning to buy
    def __init__(self):
        self.list = []
        self.total = 0.0
    
    # check if the item is in my inventory, if it is, add it to the cart
    def add(self, a, inv):
        if a.name.lower() in inv:
            #increment cart total
            self.list.append(a)
            self.total += a.price
        else:
            input("That animal cannot be found in our inventory. Press any key to continue")
    
    def show(self):
        for i in self.list:
            print(i)
    
    def delete(self):
        pass
    
    def checkout(self):
        pass

class Main:
    @classmethod
    def run(self):
        inv = Inventory()
        print(f'stock starts empty {inv.stock}')
        print(f'restocking.....')
        inv.restock()
        print(f'stock is now full: {inv.stock.keys()}')
        print(f"accessing a fox {inv.stock['fennec fox']['obj'].name}")
        cart = Cart()
        
        done= False
        while not done:
            co()
            cart.show()
            ask = input("Would you like to add an item? 'quit' to exit program.").lower()
            if ask == 'quit':
                done= True
            if ask== 'add':
                print(inv.stock.keys())
                animal = input("What type of animal would you like to add?").lower()
                
            if animal in inv.stock:
                print(animal)
                #animal_obj = animal['obj']
                #cart.add(animal, inv.stock.keys())
                
    
Main.run()

# %%
self.stock = {
            'animal_name': {
                'object': 'the_animal_object_here',
                'quantity': 4
            },
            'other_animal_name':{
                'object': 'object',
                'quantity': 4
            }
        }
